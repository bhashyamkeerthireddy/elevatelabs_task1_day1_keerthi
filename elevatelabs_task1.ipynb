# %%
import pandas as pd
import numpy as np

import os

# %%
credits = pd.read_csv(r"C:\Users\Bhashyam Sudhakar\OneDrive\Documents\datascience\credits.csv")
titles = pd.read_csv(r"C:\Users\Bhashyam Sudhakar\OneDrive\Documents\datascience\titles.csv")

print(" Data Loaded Successfully!")
# Out:
#  Data Loaded Successfully!

# %%
credits.head(10)
credits.shape
# Out:
# (81355, 5)

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81355 entries, 0 to 81354
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  81355 non-null  int64
#  1   id         81355 non-null  object
#  2   name       81355 non-null  object
#  3   character  70532 non-null  object
#  4   role       81355 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.1+ MB

# %%
credits.drop_duplicates(inplace=True)

# %%
titles.head(20)
titles.shape
# Out:
# (6137, 15)

# %%
# Check missing values
print("\nMissing values in credits:")
print(credits.isnull().sum().sort_values(ascending=False).head(10))


print("\nMissing values in titles:")
print(titles.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Missing values in credits:
# character    10823
# person_id        0
# id               0
# name             0
# role             0
# dtype: int64
#
# Missing values in titles:
# seasons              3831
# age_certification    2743
# imdb_votes            484
# imdb_score            468
# imdb_id               396
# tmdb_score            252
# tmdb_popularity        76
# description            23
# runtime                 0
# title                   0
# dtype: int64

# %%
titles['seasons'] = titles.apply(
    lambda x: 0 if x['type'] == 'MOVIE' and pd.isnull(x['seasons']) else x['seasons'],
    axis=1
)

titles['seasons'] = titles.groupby('type')['seasons'].transform(lambda x: x.fillna(x.median()))
titles['age_certification'] = titles['age_certification'].fillna('Unknown')
titles['imdb_votes'] = titles['imdb_votes'].fillna(test['imdb_votes'].median())
titles['imdb_score'] = titles.groupby('type')['imdb_score'].transform(
    lambda x: x.fillna(x.median())
)
titles['imdb_id'] = titles['imdb_id'].fillna('unknown_id')
titles['tmdb_score'] = titles.groupby('type')['tmdb_score'].transform(
    lambda x: x.fillna(x.median())
)
titles['tmdb_popularity'] = titles['tmdb_popularity'].fillna(test['tmdb_popularity'].median())
titles['description'] = titles['description'].fillna('No description available')

# %%
titles.head(15)
# Out:
#           id                                title   type  \
# 0   ts300399  Five Came Back: The Reference Films   SHOW
# 1    tm82169                                Rocky  MOVIE
# 2    tm17823                               Grease  MOVIE
# 3   tm191099                            The Sting  MOVIE
# 4    tm69975                             Rocky II  MOVIE
# 5   tm127384      Monty Python and the Holy Grail  MOVIE
# 6    tm17249                         Animal House  MOVIE
# 7    ts22164         Monty Python's Flying Circus   SHOW
# 8    tm70993                        Life of Brian  MOVIE
# 9    tm16479                      White Christmas  MOVIE
# 10   tm91699                               Heroes  MOVIE
# 11   tm12775                    Play Misty for Me  MOVIE
# 12  tm135083                        Cairo Station  MOVIE
# 13   tm69997       Richard Pryor: Live in Concert  MOVIE
# 14   tm16812                               Bandie  MOVIE
#
# ...

# %%
print(titles.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# dtype: int64

# %%
titles.drop_duplicates(inplace=True)

# %%
titles['release_year'] = pd.to_datetime(titles['release_year'], format='%Y')

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6137 entries, 0 to 6136
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    6137 non-null   object
#  1   title                 6137 non-null   object
#  2   type                  6137 non-null   object
#  3   description           6137 non-null   object
#  4   release_year          6137 non-null   datetime64[ns]
#  5   age_certification     6137 non-null   object
#  6   runtime               6137 non-null   int64
#  7   genres                6137 non-null   object
#  8   production_countries  6137 non-null   object
#  9   seasons               6137 non-null   float64
#  10  imdb_id               6137 non-null   object
#  11  imdb_score            6137 non-null   float64
#  12  imdb_votes            6137 non-null   float64
#  13  tmdb_popularity       6137 non-null   float64
# ...

# %%
titles.shape
# Out:
# (6137, 15)

# %%
credits.shape
# Out:
# (81355, 5)
